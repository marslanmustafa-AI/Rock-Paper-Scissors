# %%
from ultralytics import YOLO

# %%
model = YOLO('./runs/classify/train/weights/best.pt')
print("Model loaded from best.pt")
# Out:
# Model loaded from best.pt

# %%
# img = load_img('./data/rps-test-set/paper/testpaper01-17.png', target_size=(150, 150))
# img = load_img('./data/rps-test-set/rock/testrock01-04.png', target_size=(150, 150))
# img = load_img('./data/rps-test-set/scissors/testscissors04-29.png', target_size=(150, 150))

img = model('./images/scissors.jpg')
# img = load_img('./images/rock.jpg', target_size=(150, 150))
# img = load_img('./images/scissors.jpg', target_size=(150, 150))
# Out:
# image 1/1 /Users/apple/Documents/Code/AI/Projects/DL/notebooks/yolo/images/scissors.jpg: 160x160 scissors 0.99, paper 0.01, rock 0.00, 8.6ms
# Speed: 7.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import keras
from keras.utils import load_img

# Load image
img = load_img('./images/paper.jpg', target_size=(150, 150))
# img = load_img('./images/rock.jpg', target_size=(150, 150))
# img = load_img('./images/scissors1.jpg', target_size=(150, 150))

# Preprocess
img_array = keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # batch dimension

# Predict
predictions = saved_model.predict(img_array)
predicted_class = class_names[np.argmax(predictions[0])]
confidence = 100 * np.max(predictions[0])

# -------- Visualization --------
plt.figure(figsize=(10, 4))

# Show Image
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.title(f"Prediction: {predicted_class}\nConfidence: {confidence:.2f}%")
plt.axis('off')

# Show Probabilities
plt.subplot(1, 2, 2)
plt.bar(class_names, predictions[0])
plt.title("Class Probabilities")
plt.xlabel("Classes")
plt.ylabel("Confidence")

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
