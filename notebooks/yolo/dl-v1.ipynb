# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo26n-cls.pt")

# %%
results = model.train(
  data="../data",
  epochs=20,
  patience=5,
  imgsz=150,
  batch=32,
  lr=0.001
  )
# Out:
# Ultralytics 8.4.46 🚀 Python-3.11.14 torch-2.10.0 CPU (Apple M1 Pro)
# ...

# %%
model = YOLO("yolo26n.pt")

# %%
results = model.predict(source="/Users/apple/Documents/Code/AI/Projects/DL/notebooks/images/image.png", save=True)
print(results[0].boxes)
# Out:
# image 1/1 /Users/apple/Documents/Code/AI/Projects/DL/notebooks/images/image.png: 448x640 1 person, 2 bicycles, 1 car, 40.4ms
# Speed: 2.1ms preprocess, 40.4ms inference, 0.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /Users/apple/Documents/Code/AI/Projects/DL/notebooks/yolo/runs/detect/predict
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2., 1., 0., 1.])
# conf: tensor([0.9185, 0.9058, 0.8900, 0.3734])
# data: tensor([[3.9230e+02, 2.5100e+02, 6.9988e+02, 4.0896e+02, 9.1846e-01, 2.0000e+00],
#         [2.4792e+02, 3.3673e+02, 4.8240e+02, 5.8404e+02, 9.0579e-01, 1.0000e+00],
#         [2.6650e+02, 1.8590e+02, 4.1997e+02, 5.2099e+02, 8.9005e-01, 0.0000e+00],
#         [7.9898e+01, 2.7671e+02, 1.7566e+02, 3.2650e+02, 3.7341e-01, 1.0000e+00]])
# id: None
# is_track: False
# orig_shape: (700, 1050)
# shape: torch.Size([4, 6])
# xywh: tensor([[546.0916, 329.9810, 307.5734, 157.9660],
# ...
